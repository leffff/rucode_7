# %% [markdown]
# # Data

# %%
def read_texts(path):
    with open(path, "r") as fin:
        return [word.strip() for word in fin.readlines()]

# %%
DATA = "data/"
train_path = DATA + "train_stresses_labels.txt"
test_path = DATA + "public_test_stresses.txt"
train_path
# Out:
# 'data/train_stresses_labels.txt'

# %%
words_train = (read_texts(train_path))
words_test = (read_texts(test_path))

len(words_train), len(words_test)
# Out:
# (588490, 294253)

# %%
words_train
# Out:
# ['аа^к',
#  'аа^ка',
#  'аа^ке',
#  'аа^ки',
#  'аа^ков',
#  'аа^ком',
#  'аа^м',
#  'аа^му',
#  'аа^нгича',
#  'аа^нгичам',
#  'ааро^не',
#  'ааро^новец',
#  'ааро^новские',
#  'ааро^новский',
#  'ааро^новца',
#  'ааро^новцами',
#  'ааро^новце',
#  'ааро^новцы',
#  'ааро^новщин',
#  'ааро^новщинами',
#  'ааро^новщинах',
#  'ааро^новщины',
#  'ааро^ну',
#  'а^ахенец',
#  'аа^хенский',
#  'абаа^сами',
#  'абаа^сов',
#  'абаа^су',
#  'абаа^сы',
#  'абада^н',
#  'абада^нец',
#  'абада^нках',
#  'абада^нки',
#  'абада^нкою',
#  'абада^нку',
#  'абада^нские',
#  'абада^нский',
#  'абада^нца',
#  'абада^нцами',
#  'абада^нце',
#  'абада^нцев',
#  'абада^нцы',
#  'абажу^рами',
#  'абажу^рно',
#  'абажу^рны',
#  'абажу^ров',
#  'абажу^ру',
#  'абази^ею',
#  'абази^на',
#  'абази^нам',
#  'абази^нки',
#  'абази^нкою',
#  'абази^нские',
#  'абази^нско',
#  'абази^нца',
#  'абази^нцу',
#  'абази^нцы',
#  'абази^я',
#  'аба^зов',
#  'аба^зом',
#  'аба^им',
#  'аба^й',
#  'аба^к',
#  'аба^кам',
#  'аба^ками',
#  'абака^н',
#  'абака^не',
#  'абака^нский',
#  'абако^вый',
#  'аба^ком',
#  'абако^ст',
#  'абако^стам',
#  'абако^сте',
#  'абако^стом',
#  'абаксиа^льный',
#  'абактэриа^льный',
#  'абаку^м',
#  'абаку^мыч',
#  'абаку^мыча',
#  'абаку^мычам',
#  'абаку^мычах',
#  'аба^лкин',
#  'абало^н',
#  'абало^ном',
#  'аба^ргами',
#  'аба^ргах',
#  'аба^рге',
#  'аба^ргой',
#  'аба^ргою',
#  'абарогно^з',
#  'абарогно^за',
#  'абарогно^зу',
#  'аба^с',
#  'абастума^нскую',
#  'аба^тец',
#  'аба^тмэнт',
#  'аба^тов',
#  'абато^нам',
#  'абато^нах',
#  'абато^ны',
#  'аба^тский',
#  'аба^тства',
#  'аба^тство',
#  'аба^тствовавший',
#  'аба^тствующий',
#  'абатча^нка',
#  'абаци^ст',
#  'аба^ш',
#  'аба^шем',
#  'абба^',
#  'абба^с',
#  'аббаси^дский',
#  'абба^там',
#  'абба^тами',
#  'аббати^сах',
#  'аббати^сою',
#  'аббати^сса',
#  'абба^том',
#  'абба^тства',
#  'абба^тствам',
#  'абба^тствах',
#  'абба^тствовать',
#  'абба^тству',
#  'аббо^ю',
#  'аббревиату^р',
#  'аббревиату^рам',
#  'аббревиату^рами',
#  'аббревиату^рах',
#  'аббревиату^ре',
#  'аббревиату^рен',
#  'аббревиату^рка',
#  'аббревиату^рки',
#  'аббревиату^рку',
#  'аббревиату^рна',
#  'аббревиату^рная',
#  'аббревиату^рно',
#  'аббревиату^рное',
#  'аббревиату^рному',
#  'аббревиату^рною',
#  'аббревиату^рные',
#  'аббревиату^рный',
#  'аббревиату^рным',
#  'аббревиату^рными',
#  'аббревиату^рных',
#  'аббревиату^ру',
#  'аббревиату^ры',
#  'аббревиа^цией',
#  'аббревиа^ций',
#  'аббревиа^цию',
#  'аббревиа^ция',
#  'аббревии^ровавши',
#  'аббревии^ровавшись',
#  'аббревии^ровать',
#  'аббревии^роваться',
#  'аббревии^руя',
#  'аббревии^руясь',
#  'абве^ровский',
#  'а^бвером',
#  'а^бверу',
#  'абга^зный',
#  'абгалды^ри',
#  'абгалды^рь',
#  'абгалды^рях',
#  'абга^р',
#  'абгомото^пии',
#  'абгомото^пий',
#  'абгомото^пию',
#  'абгомото^пиям',
#  'абгомото^пиями',
#  'абгомото^пиях',
#  'абгрэ^йдик',
#  'абда^ла',
#  'абда^лах',
#  'абда^ле',
#  'абда^лов',
#  'абдери^т',
#  'абдери^тах',
#  'абдери^тов',
#  'абдери^том',
#  'абдери^ту',
#  'абджа^д',
#  'абдика^ции',
#  'абдика^ций',
#  'абдикацио^нный',
#  'абдика^цию',
#  'абдика^циями',
#  'абдика^циях',
#  'абдо^менах',
#  'абдо^менов',
#  'абдо^меном',
#  'абдо^мены',
#  'абдоминалги^я',
#  'абдоминализа^ция',
#  'абдомина^льна',
#  'абдомина^льная',
#  'абдомина^льнее',
#  'абдомина^льно',
#  'абдомина^льной',
#  'абдомина^льном',
#  'абдомина^льною',
#  'абдомина^льны',
#  'абдомина^льными',
#  'абдомина^льных',
#  'абдоминоаорта^льный',
#  'абдоминогистеротоми^ей',
#  'абдоминогистеротоми^ею',
#  'абдоминогистеротоми^и',
#  'абдоминогистеротоми^й',
#  'абдоминогистеротоми^ю',
#  'абдоминогистеротоми^я',
#  'абдоминогистеротоми^ями',
#  'абдоминогистеротоми^ях',
#  'абдоминогистерэктоми^ей',
#  'абдоминогистерэктоми^ею',
#  'абдоминогистерэктоми^и',
#  'абдоминогистерэктоми^й',
#  'абдоминогистерэктоми^ю',
#  'абдоминогистерэктоми^я',
#  'абдоминогистерэктоми^ям',
#  'абдоминогистерэктоми^ях',
#  'абдоминомедиастина^льный',
#  'абдоминоперикардиостоми^ей',
#  'абдоминоперикардиостоми^ею',
#  'абдоминоперикардиостоми^и',
#  'абдоминоперикардиостоми^я',
#  'абдоминоперикардиостоми^ям',
#  'абдоминоперикардиостоми^ях',
#  'абдоминопла^стик',
#  'абдоминопла^стикам',
#  'абдоминопла^стиками',
#  'абдоминопла^стиках',
#  'абдоминопла^стике',
#  'абдоминопла^стики',
#  'абдоминопла^стикой',
#  'абдоминопла^стику',
#  'абдоминоскопи^й',
#  'абдоминоскопи^ю',
#  'абдоминоскопи^я',
#  'абдоминоскопи^ями',
#  'абдоминоскопи^ях',
#  'абдрага^нам',
#  'абдрага^не',
#  'абдрага^ном',
#  'абдрага^ну',
#  'абдрага^ны',
#  'абдукта^нт',
#  'абдукта^нта',
#  'абдукта^нтам',
#  'абдукта^нтами',
#  'абдукта^нтах',
#  'абдукта^нте',
#  'абдукта^нту',
#  'абдукта^нты',
#  'абду^ктора',
#  'абду^кторам',
#  'абду^кторная',
#  'абду^кторней',
#  'абду^кторному',
#  'абду^кторною',
#  'абду^кторные',
#  'абду^кторными',
#  'абду^ктором',
#  'абду^ктору',
#  'абду^кторы',
#  'абду^кцией',
#  'абду^кциею',
#  'абду^кции',
#  'абду^кций',
#  'абдукцио^нный',
#  'абду^кцию',
#  'абду^кция',
#  'абду^кциям',
#  'абду^кциями',
#  'абду^кциях',
#  'абду^линец',
#  'абду^линский',
#  'абдурахма^ну',
#  'абдэри^т',
#  'абеве^г',
#  'абеве^га',
#  'абеве^гам',
#  'абевегеде^ек',
#  'абевегеде^йка',
#  'абевегеде^йкам',
#  'абевегеде^йке',
#  'абевегеде^йкою',
#  'абеве^ги',
#  'а^белев',
#  'а^белева',
#  'а^белевостей',
#  'а^белевость',
#  'а^белевостям',
#  'абелианиза^цией',
#  'абелианиза^циею',
#  'абелианиза^ции',
#  'абелианиза^ций',
#  'абелианиза^цию',
#  'абе^лией',
#  'абе^лий',
#  'абели^тах',
#  'абели^те',
#  'абели^ту',
#  'абели^ты',
#  'абе^лиям',
#  'абе^лиями',
#  'абельмо^ша',
#  'абельмо^шах',
#  'абельмо^ше',
#  'абельмо^ши',
#  'а^бельская',
#  'а^белю',
#  'абеля^ра',
#  'абенакии^т',
#  'абенакии^ты',
#  'аберди^на',
#  'аберди^не',
#  'аберра^нтен',
#  'аберра^нтно',
#  'аберра^нтны',
#  'аберра^торам',
#  'аберра^торе',
#  'аберра^цией',
#  'аберра^циею',
#  'аберрацио^нен',
#  'аберрацио^нно',
#  'аберрацио^нное',
#  'аберрацио^нной',
#  'аберрацио^нною',
#  'аберрацио^нную',
#  'аберрацио^нны',
#  'аберрацио^нный',
#  'аберрацио^нным',
#  'аберрацио^нных',
#  'аберра^ция',
#  'аберра^циям',
#  'аберра^циях',
#  'аберри^ровавший',
#  'аберри^ровать',
#  'аберри^руемый',
#  'аберри^руя',
#  'аберрометри^ческий',
#  'аберроско^п',
#  'аберроскопи^чески',
#  'аберроскопи^ческий',
#  'абе^с',
#  'абеси^в',
#  'абе^сом',
#  'абе^су',
#  'абе^сы',
#  'абеталипопротеинеми^ей',
#  'абеталипопротеинеми^ею',
#  'абеталипопротеинеми^и',
#  'абеталипопротеинеми^й',
#  'абеталипопротеинеми^ю',
#  'абеталипопротеинеми^ям',
#  'абеталипопротеинеми^ями',
#  'абеталипопротеинеми^ях',
#  'абецеда^риев',
#  'абецеда^рии',
#  'абецеда^рий',
#  'абецеда^риям',
#  'абза^цам',
#  'абза^цами',
#  'абза^цев',
#  'абза^цный',
#  'абздо^льц',
#  'абздо^льцем',
#  'абздо^льцу',
#  'абзели^ловец',
#  'абзели^ловский',
#  'абзе^тцера',
#  'абзе^тцерами',
#  'абзе^тцере',
#  'абзе^тцеров',
#  'абзе^тцеру',
#  'абзе^тцеры',
#  'абзи^ма',
#  'абзи^мам',
#  'абзи^мами',
#  'абзи^мах',
#  'абзи^ме',
#  'абзи^му',
#  'абига^йль',
#  'абиджа^нец',
#  'абиджа^нка',
#  'абиети^нах',
#  'абиети^нов',
#  'абиети^нова',
#  'абиети^ново',
#  'абиети^новы',
#  'абиети^новый',
#  'абиети^ном',
#  'абила^та',
#  'абилита^ции',
#  'абилитацио^нный',
#  'абилита^ция',
#  'аби^лками',
#  'аби^лке',
#  'аби^лки',
#  'аби^лкой',
#  'аби^лку',
#  'аби^нный',
#  'аби^нск',
#  'абинча^нин',
#  'абиогене^зам',
#  'абиогене^зах',
#  'абиогене^зе',
#  'абиогене^зом',
#  'абиогенети^чески',
#  'абиоге^нно',
#  'абиоге^нный',
#  'абиогенэ^з',
#  'абио^з',
#  'абио^зам',
#  'абио^зе',
#  'абио^зов',
#  'абио^зом',
#  'абио^зы',
#  'абиосесто^нам',
#  'абиосесто^нах',
#  'абиосесто^ном',
#  'абио^там',
#  'абио^тах',
#  'абио^те',
#  'абиоти^чески',
#  'абиоти^ческий',
#  'абиоти^чно',
#  'абио^той',
#  'абиотрофи^и',
#  'абиотрофи^ю',
#  'абиотрофи^ях',
#  'абио^ту',
#  'абиофизиоло^гиею',
#  'абиофизиоло^гий',
#  'абиофизиоло^гию',
#  'абиофизиоло^гиях',
#  'абиоце^н',
#  'абиоце^нах',
#  'абиоце^ном',
#  'абиоце^ны',
#  'абиса^ль',
#  'абиса^льный',
#  'абиси^нка',
#  'абиси^нский',
#  'абисса^ли',
#  'абисса^ль',
#  'абисса^льный',
#  'абисса^лям',
#  'абисса^лями',
#  'абисси^нец',
#  'абисси^ния',
#  'абисси^нка',
#  'абисси^нска',
#  'абисси^нски',
#  'абисси^нский',
#  'абисси^нца',
#  'абисси^нцам',
#  'абисси^нцами',
#  'абисси^нцах',
#  'абисси^нце',
#  'абисси^нцев',
#  'абисси^нцем',
#  'абисси^нцы',
#  'абиссопелагиа^ль',
#  'абиту^р',
#  'абиту^ра',
#  'абиту^ре',
#  'абитурие^нт',
#  'абитурие^нткам',
#  'абитурие^нтке',
#  'абитурие^нткою',
#  'абитурие^нтку',
#  'абитурие^нтный',
#  'абитурие^нтов',
#  'абитурие^нтск',
#  'абитурие^нтском',
#  'абитурие^нтскою',
#  'абитурие^нты',
#  'абитуриэ^нт',
#  'абитуриэ^нтский',
#  'абиту^рой',
#  'абиту^рский',
#  'абици^н',
#  'аблакта^циею',
#  'аблакта^ции',
#  'аблакта^циях',
#  'аблакти^ровавши',
#  'аблакти^ровавший',
#  'аблакти^ровавшийся',
#  'аблакти^ровавшись',
#  'аблакти^ровал',
#  'аблакти^ровало',
#  'аблакти^рование',
#  'аблакти^рованием',
#  'аблакти^ровании',
#  'аблакти^рованию',
#  'аблакти^рования',
#  'аблакти^рованиям',
#  'аблакти^рованиями',
#  'аблакти^рованиях',
#  'аблакти^ровать',
#  'аблактиро^вкам',
#  'аблактиро^вках',
#  'аблактиро^вке',
#  'аблактиро^вкой',
#  'аблакти^руемый',
#  'аблакти^рует',
#  'аблакти^руешь',
#  'аблакти^руй',
#  'аблакти^рую',
#  'аблакти^рующийся',
#  'аблакти^руя',
#  'аблакти^руясь',
#  'абла^стика',
#  'абла^стикам',
#  'абла^стиками',
#  'абла^стики',
#  'абла^стикой',
#  'абла^стикою',
#  'аблати^вам',
#  'аблати^вах',
#  'аблати^вна',
#  'аблати^вны',
#  'аблати^вный',
#  'аблати^вов',
#  'аблати^вы',
#  'абла^ут',
#  'абла^утам',
#  'абла^утах',
#  'абла^утов',
#  'абла^уту',
#  'абла^ция',
#  'аблефари^ей',
#  'аблефари^ею',
#  'аблефари^и',
#  'аблефари^я',
#  'аблефаро^н',
#  'аблефаро^нам',
#  'аблефаро^нах',
#  'аблефаро^не',
#  'аблефаро^ну',
#  'аблефаро^ны',
#  'абли^ровав',
#  'абли^руя',
#  'аблютома^ниею',
#  'аблютома^нии',
#  'аблютома^ний',
#  'аблютома^ния',
#  'аблютома^ниям',
#  'аблютома^ниями',
#  'абляти^вам',
#  'абляти^ве',
#  'абляти^вен',
#  'абляти^вна',
#  'абляти^вны',
#  'абляти^вный',
#  'абляти^ву',
#  'абляти^вы',
#  'абля^тор',
#  'абля^торам',
#  'абля^торы',
#  'абля^утах',
#  'абля^уте',
#  'абля^утов',
#  'абля^утом',
#  'абля^уты',
#  'абля^циею',
#  'абля^циям',
#  'абмигра^ции',
#  'абмигра^ций',
#  'абмигра^цию',
#  'абмигра^циях',
#  'абовя^нец',
#  'абовя^нка',
#  'аболициони^зм',
#  'аболициони^змам',
#  'аболициони^змах',
#  'аболициони^зме',
#  'аболициони^зму',
#  'аболициони^змы',
#  'аболициони^стами',
#  'аболициони^стка',
#  'аболициони^стках',
#  'аболициони^стке',
#  'аболициони^стки',
#  'аболициони^сткой',
#  'аболициони^стов',
#  'аболициони^стом',
#  'аболициони^стск',
#  'аболициони^стские',
#  'аболициони^стский',
#  'аболициони^стским',
#  'аболициони^стского',
#  'аболициони^стском',
#  'аболициони^стскую',
#  'аболициони^сты',
#  'аболи^циями',
#  'аболю^цией',
#  'аболю^циею',
#  'аболю^ций',
#  'аболю^циями',
#  'аболю^циях',
#  'або^мами',
#  'або^ме',
#  'або^мов',
#  'або^му',
#  'абонеме^нта',
#  'абонеме^нтам',
#  'абонеме^нтами',
#  'абонеме^нте',
#  'абонеме^нтен',
#  'абонеме^нтна',
#  'абонеме^нтнее',
#  'абонеме^нтного',
#  'абонеме^нтной',
#  'абонеме^нтном',
#  'абонеме^нтному',
#  'абонеме^нтною',
#  'абонеме^нтными',
#  'абонеме^нтных',
#  'абонеме^нтом',
#  'абонеме^нты',
#  'абоне^нта',
#  'абоне^нтам',
#  'абоне^нтен',
#  'абоне^нтке',
#  'абоне^нтку',
#  'абоне^нтна',
#  'абоне^нтно',
#  'абоне^нтны',
#  'абоне^нтный',
#  'абоне^нтов',
#  'абоне^нтом',
#  'абоне^нтска',
#  'абоне^нтски',
#  'абоне^нтский',
#  'абоне^нтско',
#  'абоне^нты',
#  'абониме^нта',
#  'абони^ровав',
#  'абони^ровавшееся',
#  'абони^ровавшемся',
#  'абони^ровавшеюся',
#  'абони^ровались',
#  'абони^ровалось',
#  'абони^рование',
#  'абони^рований',
#  'абони^рованию',
#  'абони^рования',
#  'абони^рованиями',
#  'абони^рованного',
#  'абони^рованный',
#  'абони^ровать',
#  'абониро^вщица',
#  'абони^руемый',
#  'абони^рующегося',
#  'абони^рующееся',
#  'абони^рующейся',
#  'абони^рующемуся',
#  'абони^рующеюся',
#  'абони^рующийся',
#  'абони^рующимся',
#  'абони^рующихся',
#  'абони^рующуюся',
#  'абони^руя',
#  'абора^льно',
#  'абора^льный',
#  'аборда^жам',
#  'аборда^жем',
#  'аборда^жна',
#  'аборда^жно',
#  'аборда^жны',
#  'аборди^ровав',
#  'аборди^ровавши',
#  'аборди^ровавший',
#  'аборди^ровавшись',
#  'аборди^рованный',
#  'аборди^руясь',
#  'абориге^н',
#  'абориге^на',
#  'абориге^нам',
#  'абориге^нах',
#  'абориге^нен',
#  'абориге^нками',
#  'абориге^нках',
#  'абориге^нке',
#  'абориге^нки',
#  'абориге^нкой',
#  'абориге^нкою',
#  'абориге^нна',
#  'абориге^нная',
#  'абориге^нной',
#  'абориге^нном',
#  'абориге^нному',
#  'абориге^нною',
#  'абориге^нную',
#  'абориге^нны',
#  'абориге^нный',
#  'абориге^нным',
#  'абориге^нными',
#  'абориге^нных',
#  'абориге^нов',
#  'абориге^нские',
#  'абориге^нский',
#  'абориге^нских',
#  'абориге^ну',
#  'абориге^ншу',
#  'абориге^ны',
#  'або^ртам',
#  'аборти^вна',
#  'аборти^вны',
#  'аборти^вные',
#  'аборти^ровавший',
#  'аборти^ровавшийся',
#  'аборти^ровавшись',
#  'аборти^рованный',
#  'аборти^руемый',
#  'аборти^рующий',
#  'аборти^рующийся',
#  'аборти^руя',
#  'або^ртный',
#  'або^ртус',
#  'абортца^нга',
#  'абортца^нгам',
#  'абортца^нгах',
#  'абортца^нге',
#  'абортца^нгом',
#  'абраамя^н',
#  'абради^ровавши',
#  'абради^рование',
#  'абради^руя',
#  'абрази^в',
#  'абрази^вах',
#  'абрази^вна',
#  'абрази^вно',
#  'абрази^вного',
#  'абрази^вному',
#  'абрази^вностей',
#  'абрази^вности',
#  'абрази^вностью',
#  'абрази^вностям',
#  'абрази^вностями',
#  'абрази^вностях',
#  'абрази^вною',
#  'абрази^вную',
#  'абрази^вные',
#  'абрази^вным',
#  'абрази^вными',
#  'абрази^вных',
#  'абрази^вом',
#  'абразивосто^йкость',
#  'абрази^вы',
#  'абра^зии',
#  'абразио^нен',
#  'абразио^нна',
#  'абразио^нное',
#  'абразио^нном',
#  'абразио^нному',
#  'абразио^нными',
#  'абразио^нных',
#  'абра^зиях',
#  'абракада^бр',
#  'абракада^бра',
#  'абракада^брах',
#  'абракада^брой',
#  'абракада^брят',
#  'абра^м',
#  'абрами^т',
#  'абра^мов',
#  'абра^мский',
#  'абраха^м',
#  'абреа^кции',
#  'абреа^кция',
#  'абре^кам',
#  'абре^ках',
#  'абре^ком',
#  'абривиату^ру',
#  'абрико^с',
#  'абрико^сами',
#  'абрико^сах',
#  'абрико^сна',
#  'абрико^сно',
#  'абрико^сны',
#  'абрико^сов',
#  'абрикоти^н',
#  'абрикоти^нами',
#  'абрикоти^не',
#  'абрикоти^нов',
#  'абрикоти^ном',
#  'абрикоти^ну',
#  'абрикоти^ны',
#  'а^брис',
#  'а^бриса',
#  'а^брисам',
#  'а^брисе',
#  'а^брисен',
#  'а^бриснее',
#  'а^брисном',
#  'а^брисною',
#  'а^брисны',
#  'а^брисные',
#  'а^брисов',
#  'а^брисом',
#  'а^брису',
#  'аброга^цией',
#  'аброга^ции',
#  'аброга^цию',
#  'аброга^циями',
#  'аброга^циях',
#  'абро^сим',
#  'абро^симович',
#  'абрупти^вами',
#  'абрупти^вах',
#  'абрупти^вом',
#  'абрупти^вы',
#  'абруццезя^нка',
#  'абру^ццкий',
#  'абрюти^ровавший',
#  'абрюти^ровавшийся',
#  'абрюти^роваться',
#  'абрюти^руясь',
#  'абса^нса',
#  'абса^нсах',
#  'абса^нсов',
#  'абса^нсом',
#  'абса^нсу',
#  'абсе^нт',
#  'абсентеи^змами',
#  'абсентеи^змах',
#  'абсентеи^зме',
#  'абсентеи^змы',
#  'абсентеи^стам',
#  'абсентеи^стами',
#  'абсентеи^стах',
#  'абсентеи^стов',
#  'абсентеи^стом',
#  'абсентеи^стский',
#  'абсентеи^сту',
#  'абсентеи^сты',
#  'абсенти^змах',
#  'абсенти^змом',
#  'абсенти^змы',
#  'абсе^нтов',
#  'абсе^нту',
#  'абси^д',
#  'абси^да',
#  'абси^дами',
#  'абси^дах',
#  'абси^де',
#  'абси^дою',
#  'абси^ды',
#  'абсольве^нт',
#  'абсолю^т',
#  'абсолю^та',
#  'абсолю^те',
#  'абсолюти^вен',
#  'абсолюти^вная',
#  'абсолюти^внее',
#  'абсолюти^вней',
#  'абсолюти^вного',
#  'абсолюти^вной',
#  'абсолюти^вному',
#  'абсолюти^вною',
#  'абсолюти^вную',
#  'абсолюти^вны',
#  'абсолюти^вные',
#  'абсолюти^вными',
#  'абсолютиза^цией',
#  'абсолютиза^ции',
#  'абсолютиза^ций',
#  'абсолютиза^цию',
#  'абсолютиза^циями',
#  'абсолютиза^циях',
#  'абсолютизи^ровавшийся',
#  'абсолютизи^ровавшись',
#  'абсолютизи^ровал',
#  'абсолютизи^ровало',
#  'абсолютизи^рованием',
#  'абсолютизи^ровании',
#  'абсолютизи^рованию',
#  'абсолютизи^рования',
#  'абсолютизи^рованиям',
#  'абсолютизи^рованиями',
#  'абсолютизи^руем',
#  'абсолютизи^руемый',
#  'абсолютизи^руете',
#  'абсолютизи^руйте',
#  'абсолютизи^рую',
#  'абсолютизи^рующий',
#  'абсолютизи^рующийся',
#  'абсолютизи^руясь',
#  'абсолюти^змам',
#  'абсолюти^змах',
#  'абсолюти^змов',
#  'абсолюти^зму',
#  'абсолюти^ровав',
#  'абсолюти^ровавшись',
#  'абсолюти^ровать',
#  'абсолюти^роваться',
#  'абсолюти^рующийся',
#  'абсолюти^сский',
#  'абсолюти^ст',
#  'абсолюти^ста',
#  'абсолюти^стам',
#  'абсолюти^стка',
#  'абсолюти^стск',
#  'абсолюти^стски',
#  'абсолюти^стские',
#  'абсолюти^стскими',
#  'абсолюти^стских',
#  'абсолюти^стско',
#  'абсолюти^стском',
#  'абсолюти^стскою',
#  'абсолюти^сты',
#  'абсолю^тнее',
#  'абсолю^тнейший',
#  'абсолю^тному',
#  'абсолю^тностей',
#  'абсолю^тности',
#  'абсолю^тность',
#  'абсолю^тностью',
#  'абсолю^тностями',
#  'абсолю^тною',
#  'абсолю^тную',
#  'абсолю^тными',
#  'абсолю^ты',
#  'абсолю^ция',
#  'абсорба^там',
#  'абсорбе^нтами',
#  'абсорбе^нтах',
#  'абсорбе^нтов',
#  'абсорбе^нтом',
#  'абсорбе^нту',
#  'абсорбе^нты',
#  'абсо^рберам',
#  'абсо^рберами',
#  'абсо^рберов',
#  'абсо^рбером',
#  'абсо^рберу',
#  'абсорби^ровавши',
#  'абсорби^ровавший',
#  'абсорби^ровавшийся',
#  'абсорби^ровавшись',
#  'абсорби^ровал',
#  'абсорби^ровалась',
#  'абсорби^ровались',
#  'абсорби^ровался',
#  'абсорби^рование',
#  'абсорби^рований',
#  'абсорби^рованиям',
#  'абсорби^рованиями',
#  'абсорби^ровать',
#  'абсорби^роваться',
#  'абсорби^руем',
#  'абсорби^руемый',
#  'абсорби^рует',
#  'абсорби^руетесь',
#  'абсорби^руешься',
#  'абсорби^руйтесь',
#  'абсорби^руюсь',
#  'абсорби^руют',
#  'абсорби^руются',
#  'абсорби^рующий',
#  'абсорби^рующийся',
#  'абсорби^руя',
#  'абсорби^руясь',
#  'абсорбти^вна',
#  'абсорбти^вно',
#  'абсорбти^вный',
#  'абсо^рбцией',
#  'абсо^рбций',
#  'абсорбциометри^чески',
#  'абсорбцио^нен',
#  'абсорбцио^нна',
#  'абсорбцио^ннее',
#  'абсорбцио^нней',
#  'абсорбцио^нно',
#  'абсорбцио^нное',
#  'абсорбцио^нной',
#  'абсорбцио^нном',
#  'абсорбцио^нному',
#  'абсорбцио^нною',
#  'абсорбцио^нны',
#  'абсо^рбция',
#  'абсо^рбциям',
#  'абсо^рбциями',
#  'абстенциони^ста',
#  'абстенциони^стам',
#  'абстенциони^стах',
#  'абстенциони^стом',
#  'абстине^нтам',
#  'абстине^нте',
#  'абстине^нтна',
#  'абстине^нтны',
#  'абстине^нтов',
#  'абстине^нту',
#  'абстине^нцией',
#  'абстине^нции',
#  'абстине^нций',
#  'абстине^нция',
#  ...]

# %%
words_test
# Out:
# ['аакам',
#  'ааками',
#  'ааленец',
#  'аама',
#  'аамами',
#  'аамов',
#  'аамом',
#  'аамы',
#  'аангичами',
#  'аангичах',
#  'аангиче',
#  'аангичи',
#  'аангичу',
#  'аарон',
#  'аарона',
#  'ааронов',
#  'аароновцам',
#  'аароновцах',
#  'аароновцев',
#  'аароновцем',
#  'аароновщиной',
#  'аароновщиною',
#  'аароны',
#  'аахен',
#  'абаас',
#  'абаасам',
#  'абаасах',
#  'абаасе',
#  'абаасом',
#  'абаданка',
#  'абаданке',
#  'абаданкой',
#  'абаданцем',
#  'абаддон',
#  'абадзех',
#  'абажур',
#  'абажура',
#  'абажурах',
#  'абажурна',
#  'абажурный',
#  'абажуродержатель',
#  'абажуры',
#  'абазин',
#  'абазинкам',
#  'абазинками',
#  'абазинку',
#  'абазином',
#  'абазинска',
#  'абазински',
#  'абазину',
#  'абазинце',
#  'абазию',
#  'абазой',
#  'абайя',
#  'абаканец',
#  'абаках',
#  'абакостами',
#  'абакостах',
#  'абактериально',
#  'абактериальный',
#  'абактинальный',
#  'абакумычами',
#  'абакумыче',
#  'абакумычем',
#  'абалона',
#  'абалонами',
#  'абалоне',
#  'абалонов',
#  'абами',
#  'абанамат',
#  'абант',
#  'абарг',
#  'абаргам',
#  'абаргу',
#  'абарогнозия',
#  'абарогнозом',
#  'абат',
#  'абатиса',
#  'абатонами',
#  'абатоне',
#  'абатоном',
#  'абатуров',
#  'абатчанин',
#  'абачи',
#  'абашка',
#  'абашой',
#  'аббаси',
#  'аббатах',
#  'аббатисами',
#  'аббатисой',
#  'аббатисы',
#  'аббатовыми',
#  'аббатский',
#  'аббатствами',
#  'аббатстве',
#  'аббатство',
#  'аббатствовав',
#  'аббатством',
#  'аббатствуя',
#  'аббаты',
#  'аббой',
#  'аббревиатура',
#  'аббревиатурке',
#  'аббревиатуркой',
#  'аббревиатурнее',
#  'аббревиатурного',
#  'аббревиатурной',
#  'аббревиатурном',
#  'аббревиатурой',
#  'аббревиациею',
#  'аббревиировав',
#  'абброморфема',
#  'аббу',
#  'аббы',
#  'абвахты',
#  'абвера',
#  'абвере',
#  'абвэровец',
#  'абвэровский',
#  'абгаз',
#  'абгалдырей',
#  'абгалдырем',
#  'абгалдыря',
#  'абгалдырям',
#  'абгалдырями',
#  'абгомотопией',
#  'абгомотопиею',
#  'абгомотопия',
#  'абдал',
#  'абдалам',
#  'абдалами',
#  'абдалом',
#  'абдалы',
#  'абдерита',
#  'абдеритами',
#  'абдерите',
#  'абдест',
#  'абдеста',
#  'абдестом',
#  'абдикацией',
#  'абдикация',
#  'абдомен',
#  'абдоменам',
#  'абдоминален',
#  'абдоминальное',
#  'абдоминальному',
#  'абдоминальную',
#  'абдоминальные',
#  'абдоминальный',
#  'абдоминальным',
#  'абдоминизация',
#  'абдоминогистеротомиям',
#  'абдоминогистерэктомиями',
#  'абдоминоперикардиостомий',
#  'абдоминопластика',
#  'абдоминопластикою',
#  'абдоминоскопиею',
#  'абдоминоскопии',
#  'абдраганов',
#  'абдрахман',
#  'абдуктор',
#  'абдукторами',
#  'абдукторах',
#  'абдукторном',
#  'абдукторный',
#  'абдукторов',
#  'абдулла',
#  'абдуллы',
#  'абевегами',
#  'абевегах',
#  'абевегедейках',
#  'абевегою',
#  'абелевостях',
#  'абелианизация',
#  'абелианизациям',
#  'абелианизациями',
#  'абелиею',
#  'абелии',
#  'абелитам',
#  'абелию',
#  'абель',
#  'абельмош',
#  'абельмошами',
#  'абельмошем',
#  'абельн',
#  'абеля',
#  'абердинец',
#  'абердинский',
#  'аберрантна',
#  'аберрантный',
#  'аберратор',
#  'аберраторах',
#  'аберрации',
#  'аберрационна',
#  'аберрационная',
#  'аберрационнее',
#  'аберрационного',
#  'аберрационном',
#  'аберрационному',
#  'аберрационные',
#  'аберрациями',
#  'аберрировавшийся',
#  'аберрировавшись',
#  'аберрироваться',
#  'аберрирующий',
#  'аберрирующийся',
#  'аберрометр',
#  'абеса',
#  'абесами',
#  'абесивы',
#  'абессивом',
#  'абессиву',
#  'абессивы',
#  'абеталипопротеинемия',
#  'абецедарию',
#  'абецедария',
#  'абецедариями',
#  'абецедариях',
#  'абзац',
#  'абзацем',
#  'абзацы',
#  'абздольца',
#  'абзелиловка',
#  'абзим',
#  'абзимов',
#  'абигаль',
#  'абиджан',
#  'абиентный',
#  'абиетине',
#  'абиетины',
#  'абилка',
#  'абилкам',
#  'абилках',
#  'абилкою',
#  'абилок',
#  'абинец',
#  'абинка',
#  'абиогенезов',
#  'абиогенезы',
#  'абиозами',
#  'абиозу',
#  'абиосестон',
#  'абиосестоне',
#  'абиосестонов',
#  'абиот',
#  'абиота',
#  'абиотами',
#  'абиотою',
#  'абиотрофиям',
#  'абиоты',
#  'абиофизиологией',
#  'абиофизиологии',
#  'абиофизиология',
#  'абиофизиологиями',
#  'абиоценам',
#  'абиоценами',
#  'абиоценов',
#  'абисинец',
#  'абиссинско',
#  'абиссолит',
#  'абитуриенте',
#  'абитуриентках',
#  'абитуриенток',
#  'абитуриентского',
#  'абитуриентскую',
#  'абитуриенту',
#  'абитуриэнтка',
#  'абитурный',
#  'абитуру',
#  'абитуры',
#  'аблакат',
#  'аблактация',
#  'аблактациям',
#  'аблактировала',
#  'аблактировали',
#  'аблактирований',
#  'аблактироваться',
#  'аблактировка',
#  'аблактировками',
#  'аблактировкою',
#  'аблактировку',
#  'аблактировок',
#  'аблактируйте',
#  'аблактируют',
#  'абластике',
#  'абластику',
#  'аблатив',
#  'аблатива',
#  'аблативен',
#  'аблативно',
#  'аблауте',
#  'аблауты',
#  'аблегат',
#  'аблефарий',
#  'аблефарию',
#  'аблефариями',
#  'аблефарона',
#  'аблефаронов',
#  'аблютоманию',
#  'аблятив',
#  'аблятивах',
#  'аблятивно',
#  'аблятивов',
#  'аблятивом',
#  'абляторе',
#  'аблятором',
#  'аблятору',
#  'абляут',
#  'абляутами',
#  'абляуту',
#  'абляции',
#  'абляций',
#  'абляционный',
#  'абляциями',
#  'абмиграцией',
#  'абмиграциею',
#  'абмиграция',
#  'абмиграциям',
#  'абмиграциями',
#  'абовян',
#  'абовянский',
#  'аболицией',
#  'аболициею',
#  'аболиции',
#  'аболиций',
#  'аболиционизмом',
#  'аболиционисский',
#  'аболиционист',
#  'аболиционисток',
#  'аболиционистско',
#  'аболиционистской',
#  'аболиционистскому',
#  'аболиционистскою',
#  'аболицию',
#  'аболициях',
#  'аболюцию',
#  'аболюция',
#  'аболюциям',
#  'абом',
#  'абома',
#  'абомах',
#  'абоминация',
#  'абомом',
#  'абомы',
#  'абонементная',
#  'абонементные',
#  'абонементным',
#  'абонементодержатель',
#  'абонентами',
#  'абонентах',
#  'абонентки',
#  'абоненту',
#  'абонировавшись',
#  'абонировалась',
#  'абонировании',
#  'абонированиям',
#  'абонирующий',
#  'абонируясь',
#  'абонплата',
#  'абордажа',
#  'абордажами',
#  'абордаже',
#  'абордажей',
#  'абордажен',
#  'абордажный',
#  'абордировавшийся',
#  'абордируемый',
#  'аборигенка',
#  'аборигенку',
#  'аборигеннее',
#  'аборигенно',
#  'аборигеном',
#  'аборигенского',
#  'аборигенское',
#  'аборта',
#  'абортами',
#  'абортарий',
#  'абортах',
#  'абортивен',
#  'абортивно',
#  'абортивность',
#  'абортировав',
#  'абортируясь',
#  'абортов',
#  'абортом',
#  'абортцангами',
#  'абортцангу',
#  'аборты',
#  'абоский',
#  'абрадировать',
#  'абрадироваться',
#  'абразивная',
#  'абразивной',
#  'абразивном',
#  'абразивов',
#  'абразивщик',
#  'абразий',
#  'абразионная',
#  'абразионнее',
#  'абразионней',
#  'абразионно',
#  'абразионного',
#  'абразионной',
#  'абразионную',
#  'абразионны',
#  'абразионные',
#  'абразионным',
#  'абразию',
#  'абразиям',
#  'абракадабре',
#  'абракадаброю',
#  'абракадабры',
#  'абрамовой',
#  'абрамцево',
#  'абрамыч',
#  'абрек',
#  'абреками',
#  'абреке',
#  'абреку',
#  'абречки',
#  'абрикоса',
#  'абрикосам',
#  'абрикосик',
#  'абрикосовый',
#  'абрикосом',
#  'абрикосу',
#  'абрикотинам',
#  'абрисна',
#  'абрисное',
#  'абрисной',
#  'абрисному',
#  'абрисную',
#  'абрисным',
#  'абрисными',
#  'абрисъ',
#  'аброгациею',
#  'аброгация',
#  'аброгациям',
#  'абросимов',
#  'абросимовна',
#  'абруптива',
#  'абруптивам',
#  'абруптиве',
#  'абруптивов',
#  'абруццезянин',
#  'абруццы',
#  'абрютировав',
#  'абрютировавши',
#  'абрютировавшись',
#  'абрютировать',
#  'абрютируемый',
#  'абрютирующий',
#  'абрютируя',
#  'абсансам',
#  'абсансы',
#  'абсентах',
#  'абсентеизмам',
#  'абсентеизмов',
#  'абсентеизмом',
#  'абсентеиста',
#  'абсентеисте',
#  'абсентизма',
#  'абсентизмам',
#  'абсентизмами',
#  'абсентизмов',
#  'абсентизму',
#  'абсенты',
#  'абсидой',
#  'абсиду',
#  'абсолютен',
#  'абсолютив',
#  'абсолютивна',
#  'абсолютивное',
#  'абсолютивном',
#  'абсолютивный',
#  'абсолютивных',
#  'абсолютизациям',
#  'абсолютизировав',
#  'абсолютизировавши',
#  'абсолютизировала',
#  'абсолютизировали',
#  'абсолютизирование',
#  'абсолютизированиях',
#  'абсолютизирует',
#  'абсолютизируй',
#  'абсолютизма',
#  'абсолютизмами',
#  'абсолютировавши',
#  'абсолютирование',
#  'абсолютирующий',
#  'абсолютируясь',
#  'абсолютистах',
#  'абсолютистов',
#  'абсолютистской',
#  'абсолютистскому',
#  'абсолютистскую',
#  'абсолютисту',
#  'абсолютна',
#  'абсолютней',
#  'абсолютном',
#  'абсолютностям',
#  'абсолютны',
#  'абсолютные',
#  'абсолютный',
#  'абсолютным',
#  'абсолюту',
#  'абсорбат',
#  'абсорбата',
#  'абсорбатами',
#  'абсорбатах',
#  'абсорбату',
#  'абсорбент',
#  'абсорбента',
#  'абсорбентам',
#  'абсорбенте',
#  'абсорбер',
#  'абсорбере',
#  'абсорберы',
#  'абсорбировала',
#  'абсорбировалось',
#  'абсорбировании',
#  'абсорбированию',
#  'абсорбированный',
#  'абсорбируйся',
#  'абсорбируйте',
#  'абсорбирующая',
#  'абсорбциею',
#  'абсорбциометрический',
#  'абсорбционная',
#  'абсорбционную',
#  'абсорбционным',
#  'абсорбцию',
#  'абстенционисты',
#  'абстинент',
#  'абстинентах',
#  'абстинентный',
#  'абстиненциею',
#  'абстрагировавшееся',
#  'абстрагировавшейся',
#  'абстрагировавшемуся',
#  'абстрагировавшийся',
#  'абстрагировались',
#  'абстрагировании',
#  'абстрагированном',
#  'абстрагированный',
#  'абстрагированных',
#  'абстрагироваться',
#  'абстрагируемый',
#  'абстрагирует',
#  'абстрагируй',
#  'абстрагирующаяся',
#  'абстрагирующегося',
#  'абстрагирующей',
#  'абстрагирующеюся',
#  'абстракт',
#  'абстракте',
#  'абстрактней',
#  'абстрактности',
#  'абстрактов',
#  'абстракты',
#  'абстракции',
#  'абстракционизм',
#  'абстракционизме',
#  'абстракциониста',
#  'абстракционистка',
#  'абстракционистом',
#  'абстракционистск',
#  'абстракционистского',
#  'абстракционистской',
#  'абстракционистскою',
#  'абстракционистскую',
#  'абстракциями',
#  'абсурда',
#  'абсурдах',
#  'абсурдизация',
#  'абсурдизмам',
#  'абсурдизмов',
#  'абсурдистам',
#  'абсурдисте',
#  'абсурдна',
#  'абсурднейший',
#  'абсурдное',
#  'абсурдностями',
#  'абсурдные',
#  'абсурдом',
#  'абсурду',
#  'абсцедируя',
#  'абсцесса',
#  'абсцессам',
#  'абсцессу',
#  'абсцисс',
#  'абсциссою',
#  'абсэнтизм',
#  'абсэнтэизм',
#  'абсэнтэисский',
#  'абсэнтэистский',
#  'абугидам',
#  'абудабийский',
#  'абузус',
#  'абулией',
#  'абулия',
#  'абхава',
#  'абхаз',
#  'абхаза',
#  'абхазами',
#  'абхазки',
#  'абхазов',
#  'абхазок',
#  'абхазу',
#  'абхидхарма',
#  'абцуга',
#  'абцугов',
#  'абшайдэр',
#  'абшит',
#  'абштрихам',
#  'абштрихах',
#  'абштрихов',
#  'абштрихом',
#  'абывыгоды',
#  'абьюз',
#  'абьюзер',
#  'абьюзничать',
#  'абьюзный',
#  'аваги',
#  'авадон',
#  'авалист',
#  'авалунг',
#  'аваль',
#  'авальман',
#  'авам',
#  'аванбек',
#  'авангардах',
#  'авангардизмами',
#  'авангардист',
#  'авангардиста',
#  'авангардистами',
#  'авангардистска',
#  'авангардистским',
#  'авангардистских',
#  'авангардистской',
#  'авангардистскую',
#  'авангардность',
#  'авангардом',
#  'авандэк',
#  'авандюна',
#  'аванложе',
#  'аванложи',
#  'аванложу',
#  'аванпорты',
#  'аванпостами',
#  'аванпосте',
#  'аванпостны',
#  'аванпостов',
#  'авансе',
#  'авансика',
#  'авансировавши',
#  'авансировавший',
#  'авансировал',
#  'авансировала',
#  'авансирований',
#  'авансировать',
#  'авансироваться',
#  'авансируем',
#  'авансовая',
#  'авансовей',
#  'авансовою',
#  'авансодержатель',
#  'авансы',
#  'авантаже',
#  'авантажней',
#  'авантажны',
#  'авантажу',
#  'авантурин',
#  'авантюр',
#  'авантюрам',
#  'авантюрами',
#  'авантюризма',
#  'авантюризмов',
#  'авантюризму',
#  'авантюрин',
#  'авантюринами',
#  'авантюринова',
#  'авантюриновый',
#  'авантюристам',
#  'авантюристами',
#  'авантюристе',
#  'авантюристичен',
#  'авантюристическо',
#  'авантюристичнее',
#  'авантюристично',
#  'авантюристичную',
#  'авантюристичным',
#  'авантюристку',
#  'авантюристск',
#  'авантюристско',
#  'авантюристскую',
#  'авантюрнее',
#  'авантюрничавши',
#  'авантюрны',
#  'авантюрой',
#  'авар',
#  'авара',
#  'аваре',
#  'авариец',
#  'авариею',
#  'аварийка',
#  'аварийщик',
#  'аварками',
#  'аваркой',
#  'аварку',
#  'аваров',
#  'аварский',
#  'аваруит',
#  'аварца',
#  'аварцам',
#  'аварцев',
#  'аватарами',
#  'аватарах',
#  'аватару',
#  'авва',
#  'аввакумовский',
#  'аввалон',
#  'аввалону',
#  'аввам',
#  'аввах',
#  'авву',
#  'авгиев',
#  'авгиево',
#  'авгиевы',
#  'авгиевым',
#  'авгиевыми',
#  'авгит',
#  'авгомобилям',
#  'авгур',
#  'авгурам',
#  'авгуре',
#  'авгуры',
#  'августейш',
#  'августейша',
#  'августинизм',
#  'августинцы',
#  'августович',
#  'августовичу',
#  'августовск',
#  'августовски',
#  'августовские',
#  'августовский',
#  'августой',
#  'августор',
#  'августы',
#  'авдан',
#  'авдеевец',
#  'авдеевич',
#  'авдеевича',
#  'авдеевка',
#  'авдей',
#  'авдюхиным',
#  'авенир',
#  'авентюру',
#  'аверкий',
#  'аверсах',
#  'аверсивно',
#  'аверсивный',
#  'аверсный',
#  'авеста',
#  'авестизм',
#  'авиааварии',
#  'авиабаз',
#  'авиабаза',
#  'авиабазах',
#  'авиабазою',
#  'авиабазы',
#  'авиабезопасность',
#  'авиабензину',
#  'авиабилетах',
#  'авиабилеты',
#  'авиабой',
#  'авиабомба',
#  'авиабригад',
#  'авиабригаду',
#  'авиабригады',
#  'авиабуй',
#  'авиагоризонт',
#  'авиагоризонта',
#  'авиагоризонтов',
#  'авиагрузовой',
#  'авиагруппам',
#  'авиагруппах',
#  'авиагруппы',
#  'авиадвигателе',
#  'авиадвигателей',
#  'авиадвигателем',
#  'авиадвигателя',
#  'авиадесант',
#  'авиадесанте',
#  'авиадесантен',
#  'авиадесантная',
#  'авиадесантней',
#  'авиадесантно',
#  'авиадесантное',
#  'авиадесантны',
#  'авиадесантными',
#  'авиадивизии',
#  'авиадивизий',
#  'авиадивизию',
#  'авиадиспетчерский',
#  'авиазавод',
#  'авиазаводов',
#  'авиазаводской',
#  'авиазаводу',
#  'авиазвена',
#  'авиазвеном',
#  'авиазвену',
#  'авиазвеньев',
#  'авиаиндустрия',
#  'авиаинженера',
#  'авиаинженеры',
#  'авиаинцидент',
#  'авиакатастрофой',
#  'авиакомпаний',
#  'авиакомпаниям',
#  'авиаконвой',
#  'авиаконструктора',
#  'авиакорпусом',
#  'авиакрейсеры',
#  'авиалайнерах',
#  'авиалайнеру',
#  'авиалесоохрана',
#  'авиалинии',
#  'авиалиния',
#  'авиалиниям',
#  'авиалицензия',
#  'авиаль',
#  'авиамагистралей',
#  'авиамагистраль',
#  'авиамагистралям',
#  'авиамаркете',
#  'авиамаршрута',
#  'авиамаршрутом',
#  'авиамаршруты',
#  'авиамасло',
#  'авиаматка',
#  'авиаматкою',
#  'авиамет',
#  'авиаметеорологический',
#  'авиаметеостанция',
#  'авиамеханический',
#  'авиамоделей',
#  'авиамоделизме',
#  'авиамоделистах',
#  'авиамоделисте',
#  'авиамоделистом',
#  'авиамоделисты',
#  'авиамодельна',
#  'авиамодельная',
#  'авиамодельней',
#  'авиамодельном',
#  'авиамодельны',
#  'авиамотора',
#  'авиамоторна',
#  'авиамоторно',
#  'авиамоторного',
#  'авиамоторный',
#  'авиамоторным',
#  'авианаблюдатель',
#  'авианавигационный',
#  'авианалета',
#  'авианосец',
#  'авианосными',
#  'авианосца',
#  'авианосцем',
#  'авиаот',
#  'авиаотрасль',
#  'авиаотряда',
#  'авиаотрядам',
#  'авиаотрядами',
#  'авиаотряде',
#  'авиаотрядом',
#  'авиапатрулирование',
#  'авиапереброска',
#  'авиаперевозчика',
#  'авиаперевозчиком',
#  'авиаперелетами',
#  'авиаперелетов',
#  'авиапират',
#  'авиапиратство',
#  'авиаподдержка',
#  'авиапокрышка',
#  'авиаполком',
#  'авиапочтам',
#  'авиапочтами',
#  'авиапочте',
#  'авиапочтой',
#  'авиапочтою',
#  'авиапочты',
#  'авиапредприятие',
#  'авиапредприятием',
#  'авиапредприятии',
#  'авиапредприятиям',
#  'авиапредприятиях',
#  'авиапредставление',
#  'авиаприбор',
#  'авиаприбора',
#  'авиапромами',
#  'авиапроме',
#  'авиапрому',
#  'авиапромышленностей',
#  'авиапромышленностям',
#  'авиаразведку',
#  'авиаракета',
#  'авиаралли',
#  'авиасалон',
#  'авиасамодельщики',
#  'авиасборный',
#  'авиасев',
#  'авиасервис',
#  'авиасим',
#  'авиасообщениям',
#  'авиаспециалист',
#  'авиаспортивный',
#  'авиастроении',
#  'авиастроения',
#  'авиастроитель',
#  'авиастроительство',
#  'авиатехнику',
#  'авиатехнический',
#  'авиатика',
#  'авиаторе',
#  'авиатором',
#  'авиаторский',
#  'авиатрал',
#  'авиатранспортабельный',
#  'авиатранспортно',
#  'авиатранспорты',
#  'авиатраса',
#  'авиатрассами',
#  'авиатрассе',
#  'авиатрисса',
#  'авиаугон',
#  'авиаудар',
#  'авиаударе',
#  'авиаудары',
#  'авиаучилище',
#  'авиахимработы',
#  'авиацентр',
#  'авиацией',
#  'авиационно',
#  'авиационное',
#  'авиационному',
#  'авиационною',
#  'авиационные',
#  'авиационным',
#  'авиациям',
#  'авиачастям',
#  'авиашкол',
#  'авиашкола',
#  'авиашколами',
#  'авиашколе',
#  'авиаэвакуация',
#  'авиаэкипаж',
#  'авиаэскадрилий',
#  'авиаэскадрильею',
#  'авиаэскадрильями',
#  'авидин',
#  'авидья',
#  'авиетки',
#  'авиетку',
#  'авизент',
#  'авизироваться',
#  'авизируясь',
#  'авизовав',
#  'авизуя',
#  'авимаил',
#  'авиновицкий',
#  'авиньонец',
#  'ависта',
#  'авитаминозам',
#  'авитаминозно',
#  'авитаминозного',
#  'авитаминозной',
#  'авитаминозному',
#  'авитаминозный',
#  'авитаминозных',
#  'авитаминозу',
#  'авиуда',
#  'авифауна',
#  'авицид',
#  'авксанометр',
#  'авксентий',
#  'авлакогеновый',
#  'авлида',
#  'авогадрит',
#  'авокадовый',
#  'авосек',
#  'авосем',
#  'авост',
#  'авоськах',
#  'авоське',
#  'авоськи',
#  'авоською',
#  ...]

# %% [markdown]
# # Tokenization

# %%
unique_symbols = sorted(list(set("".join(words_train) + "".join(words_test))))
unique_symbols
# Out:
# ['^',
#  'а',
#  'б',
#  'в',
#  'г',
#  'д',
#  'е',
#  'ж',
#  'з',
#  'и',
#  'й',
#  'к',
#  'л',
#  'м',
#  'н',
#  'о',
#  'п',
#  'р',
#  'с',
#  'т',
#  'у',
#  'ф',
#  'х',
#  'ц',
#  'ч',
#  'ш',
#  'щ',
#  'ъ',
#  'ы',
#  'ь',
#  'э',
#  'ю',
#  'я',
#  'ё']

# %%
char_to_id = {
    'а': 0,
    'б': 1,
    'в': 2,
    'г': 3,
    'д': 4,
    'е': 5,
    'ё': 6,
    'ж': 7,
    'з': 8,
    'и': 9,
    'й': 10,
    'к': 11,
    'л': 12,
    'м': 13,
    'н': 14,
    'о': 15,
    'п': 16,
    'р': 17,
    'с': 18,
    'т': 19,
    'у': 20,
    'ф': 21,
    'х': 22,
    'ц': 23,
    'ч': 24,
    'ш': 25,
    'щ': 26,
    'ъ': 27,
    'ы': 28,
    'ь': 29,
    'э': 30,
    'ю': 31,
    'я': 32,
}

VOCAB_SIZE = len(list(char_to_id.keys())) + 1 # 33 russian letters and [PAD]
VOCAB_SIZE
# Out:
# 33

# %%
MAX_LEN = max([len(word) - 1 for word in words_train] + [len(word) for word in words_test])
MAX_LEN
# Out:
# 36

# %%
def create_labels_from_train_word(word):
    word.index("^")


def encode(chars):
    return [char_to_id[char] for char in chars]


def get_labels():
    return 

def get_attn_mask():
    return 

def pad(ids):
    ones = [1 for i in range(len(ids))]
    zeros = [0 for i in range(MAX_LEN - len(ids))]
    return ones + zeros


def preprocess_train_word(word):
    chars = list(word)
